# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = "plotly_white"

# %%
FILE_NAME = "grades.ods"
grades = pd.read_excel(FILE_NAME)
grades["date"] = pd.to_datetime(grades["date"])
grades
# Out:
#                          subject      test_name      grade     coeff  \
# 0                        ML_algo          lab01  18.000000  0.250000
# 1                       intro_DL          lab01  15.000000  0.500000
# 2                        ML_algo          lab02  20.000000  0.250000
# 3                   optimization      minitest1  20.000000  0.062500
# 4                   optimization      minitest2   6.000000  0.000000
# 5                   optimization      minitest3  15.000000  0.062500
# 6                   optimization      minitest4  18.000000  0.062500
# 7                   optimization      minitest5  14.000000  0.062500
# 8             data_visualization        project  18.500000  1.000000
# 9   statistical_inference_theory  final_project  15.000000  1.000000
# 10               model_selection    assignment1  18.750000  0.160000
# 11               model_selection    assignment2  20.000000  0.175000
# 12               model_selection    assignment3  17.837838  0.185000
# 13                  optimization           exam  15.000000  0.500000
# 14                  optimization            lab  18.500000  0.250000
# 15             bayesian_learning    assignment1  19.428571  0.175000
# 16                   advanced_DL    assignment1  11.000000  0.125000
# 17             bayesian_learning    assignment2  17.142857  0.175000
# 18                   advanced_DL    assignment3  20.000000  0.125000
# 19             bayesian_learning    assignment3  13.333333  0.150000
# 20             bayesian_learning           exam  13.043478  0.575000
# 21                   advanced_DL    assignment4  16.000000  0.125000
# 22            federated_learning      minitest1  15.000000  0.062500
# 23               inverse_problem    assignment1  20.000000  0.166667
# 24                   info_theory           exam  16.000000  1.000000
# 25            federated_learning      minitest2  18.000000  0.062500
#
#          date
# 0  2022-01-10
# 1  2022-01-13
# 2  2022-01-17
# 3  2022-01-18
# 4  2022-01-25
# 5  2022-02-01
# 6  2022-02-08
# 7  2022-02-15
# 8  2022-01-12
# 9  2022-02-24
# 10 2022-02-17
# 11 2022-03-10
# 12 2022-03-24
# 13 2022-02-22
# 14 2022-03-22
# 15 2022-10-26
# 16 2022-11-04
# 17 2022-11-11
# 18 2022-12-05
# 19 2022-12-12
# 20 2022-12-14
# 21 2022-12-20
# 22 2023-01-24
# 23 2023-01-20
# 24 2023-02-06
# 25 2023-02-08

# %%
grades.dtypes
# Out:
# subject              object
# test_name            object
# grade               float64
# coeff               float64
# date         datetime64[ns]
# dtype: object

# %%
px.scatter(
    data_frame=grades,
    x="date",
    y="grade",
    color="subject",
    size="coeff",
)
