# %%
import pandas as pd
import plotly.express as px

# %%
FILE_NAME = "grades.ods"
df = pd.read_excel(FILE_NAME)
df["date"] = pd.to_datetime(df["date"])
df
# Out:
#                          subject      test_name      grade   coeff       date
# 0                        ML_algo          lab01  18.000000  0.2500 2022-01-10
# 1                       intro_DL          lab01  15.000000  0.5000 2022-01-13
# 2                        ML_algo          lab02  20.000000  0.2500 2022-01-17
# 3                   optimization      minitest1  20.000000  0.0625 2022-01-18
# 4                   optimization      minitest2   6.000000  0.0000 2022-01-25
# 5                   optimization      minitest3  15.000000  0.0625 2022-02-01
# 6                   optimization      minitest4  18.000000  0.0625 2022-02-08
# 7                   optimization      minitest5  14.000000  0.0625 2022-02-15
# 8             data_visualization        project  18.500000  1.0000 2022-01-12
# 9   statistical_inference_theory  final_project  15.000000  1.0000 2022-02-24
# 10               model_selection    assignment1  18.750000  0.1600 2022-02-17
# 11               model_selection    assignment2  20.000000  0.1750 2022-03-10
# 12               model_selection    assignment3  17.837838  0.1850 2022-03-24
# 13                  optimization           exam  15.000000  0.5000 2022-02-22
# 14                  optimization            lab  18.500000  0.2500 2022-03-22
# 15             bayesian_learning    assignment1  19.428571  0.1750 2022-10-26
# 16             bayesian_learning    assignment2  17.142857  0.1750 2022-11-11

# %%
df.dtypes
# Out:
# subject              object
# test_name            object
# grade               float64
# coeff               float64
# date         datetime64[ns]
# dtype: object

# %%
px.scatter(
    data_frame=df,
    x="date",
    y="grade",
    color="subject",
    size="coeff",
)
