# %%
import numpy as np

# %%
filename = "../data/human36m/data_3d_h36m.npz"
with np.load(filename, allow_pickle=True) as f:
  data = f["positions_3d"]

# %%
data.item()["S1"]["Directions 1"]
# Out:
# array([[[-0.091679  ,  0.15440401,  0.907261  ],
#         [-0.22323565,  0.16380551,  0.89053416],
#         [-0.18847029,  0.01407711,  0.4751688 ],
#         ...,
#         [-0.3011048 , -0.03794557,  0.86150104],
#         [-0.37928614, -0.01824484,  0.7118155 ],
#         [-0.37928614, -0.01824484,  0.7118155 ]],
#
#        [[-0.09140731,  0.15513   ,  0.907313  ],
#         [-0.22298448,  0.16425677,  0.8905954 ],
#         [-0.18819962,  0.01445323,  0.47525877],
#         ...,
#         [-0.29802272, -0.03787444,  0.8635451 ],
#         [-0.37638935, -0.02101831,  0.7136093 ],
#         [-0.37638935, -0.02101831,  0.7136093 ]],
#
#        [[-0.0911309 ,  0.155888  ,  0.90735304],
#         [-0.22272266,  0.16478354,  0.89062566],
#         [-0.1879147 ,  0.01491121,  0.47531578],
#         ...,
#         [-0.29595828, -0.03707071,  0.8653253 ],
#         [-0.37394598, -0.022425  ,  0.7149603 ],
#         [-0.37394598, -0.022425  ,  0.7149603 ]],
#
#        ...,
#
# ...
