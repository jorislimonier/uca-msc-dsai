# %%
install.packages("VBLPCM")
# Out:
# Installing package into ‘/home/joris/R/x86_64-pc-linux-gnu-library/4.2’
# (as ‘lib’ is unspecified)

# %%
library(VBLPCM)
library(network)

# %%
monks <- read.csv("sampson_monks.txt")
# drop the first column
monks <- monks[,-1]

# %%
monks_net <- as.network(as.matrix(monks))
plot(vblpcmfit(vblpcmstart(monks_net, G=1)), main="Monks")
# Out:
# 1 / 50 iterations
# 2 / 50 iterations
# 3 / 50 iterations
# 4 / 50 iterations
# 5 / 50 iterations
# 6 / 50 iterations
# 7 / 50 iterations
# 8 / 50 iterations
# 9 / 50 iterations
# 10 / 50 iterations
# 11 / 50 iterations
# 12 / 50 iterations
# *************************************************
# All converged after 13 iterations
# *************************************************
# KL distance to true posterior is  -472.9143 + constant
# Plot with title “Monks”
