# %%
# install.packages("blockmodels")
library("blockmodels")

# %%
npc <- 20 # nodes per class
n_groups <- 3 # number of groups
n <- npc * n_groups # total number of nodes
Z <- diag(n_groups) %x% matrix(1, nrow = npc, ncol = 1) # group membership matrix
P <- matrix(runif(n_groups * n_groups, 0, 0.25), n_groups, n_groups) # probability matrix
P <- rbind(
  c(0.2, 0.01, 0.01),
  c(0.02, 0.15, 0.01),
  c(0.01, 0.02, 0.25)
) # probability matrix
M <- 1 * matrix(runif(n * n), n, n) < Z %*% P %*% t(Z) # adjacency matrix
image(M)

library(sna)
gplot(M)
# Out:
# plot without title
# plot without title

# %%
model <- BM_bernoulli("SBM", M, verbosity = 1, explore_max = 4)
model$estimate()
# Out:
# -> Estimation for 1 groups
# -> Computation of eigen decomposition used for initalizations
#
# -> Pass 1
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# -> Pass 2
# plot without title

# %%
which.max(model$ICL)
# Out:
# [1] 3

# %%
cls <- apply(model$model_parameters[[3]]$pi, 1, which.max)
gplot(M,
  edge.col = "lightgray",
  vertex.col = cls,
  usecurve = TRUE,
)
# Out:
# plot without title

# %%
n <- 100
rho <- c(30, 30, 30, 3) / 93
Z <- t(rmultinom(n, 1, rho))
P <- rbind(
  c(0.2, 0.01, 0.01, 0.3),
  c(0.02, 0.25, 0.01, 0.3),
  c(0.01, 0.01, 0.3, 0.3),
  c(0.001, 0.001, 0.001, 0.01)
) # probability matrix
M <- 1 * matrix(runif(n * n), n, n) < Z %*% P %*% t(Z) # adjacency matrix
image(M)

library(sna)
gplot(M, usecurve = TRUE, edge.col = "lightgray", vertex.col = max.col(Z))
# Out:
# plot without title
# plot without title

# %%
model <- BM_bernoulli("SBM", M, verbosity = 1, explore_max = 4)
model$estimate()
# Out:
# -> Estimation for 1 groups
# -> Computation of eigen decomposition used for initalizations
#
# -> Pass 1
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# -> Pass 2
# plot without title

# %%
which.max(model$ICL)
# Out:
# [1] 3

# %%
Z.sbm <- model$membership
Z.sbm
# Out:
# Error in envRefInferField(x, what, getClass(class(x)), selfEnv): ‘membership’ is not a valid field or method name for reference class “BM_bernoulli”
# Traceback:
#
# 1. model$membership
# 2. model$membership
# 3. envRefInferField(x, what, getClass(class(x)), selfEnv)
# 4. stop(gettextf("%s is not a valid field or method name for reference class %s",
#  .     sQuote(field), dQuote(thisClass@className)), domain = NA)
