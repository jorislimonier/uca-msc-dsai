# %%
# install.packages("igraph")

# %%
source("practice01.R")

# make a graph from the adjacency matrix
g <- graph.adjacency(mat_a, mode="undirected")
plot(g)
# Out:
# Plot with title “”

# %%
# make a graph from the adjacency matrix
g <- graph.adjacency(mat_b, mode="undirected")
plot(g)
# Out:
# Plot with title “”

# %%
degree(g)
# Out:
# [1] 4 1 2 2 3

# %%
signature <- function (g, max=10) {
  clqs <- cliques(g)
  clique_lengths <- rep(0, max)
  for (i in clqs){
    len <- length(i)
    clique_lengths[len] <- clique_lengths[len] + 1
  }
  clique_lengths
  barplot(clique_lengths)
}

signature(g)
# Out:
# plot without title
